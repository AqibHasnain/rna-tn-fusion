# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy as sp

import pickle 

import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
from torch.optim.lr_scheduler import ExponentialLR

from torch_geometric.nn import SGConv, GCNConv
from torch_geometric.data import Data

# %% [markdown]
# ### Preprocessing RNA and Tn datasets
# !!!: RNA data metadata cols don't match Tn data metadata cols
#
# Don't need them to match exactly, but would prefer the same metadata for each modality

# %%
with open('2_PreprocessedData_RbTnSeq.pickle', 'rb') as handle:
    tn = pickle.load(handle)  

with open('2_PreprocessedData_RNASeq_OD.pickle', 'rb') as handle:
    rna = pickle.load(handle)

# %% [markdown]
# Put the data in AnnData format

# %%
rna['X'] = rna['X'].T
rna['X'].index = rna['X'].index.astype(str)
rna['metadata'].index = rna['metadata'].index.astype(str)
rna['metadata'].reset_index(inplace=True,drop=True)

rnadata = sc.AnnData(rna['X'])
rnadata.obs = rna['metadata']

# %%
tn['X'] = tn['X'].T
tn['X'].index = tn['X'].index.astype(str)
tn['metadata'].index = tn['metadata'].index.astype(str)

tndata = sc.AnnData(tn['X'])
tndata.obs = tn['metadata']

# %% [markdown]
# Subset the genes to those in common between RNA and Tn

# %%
genes_in_common = list(set(rnadata.var_names).intersection(set(tndata.var_names)) )

# SUBSET TO ONLY 250 GENES TO MAKE MODEL SETUP EASIER
np.random.seed(0)

random_genes = np.random.choice(range(len(genes_in_common)), 250, replace=False)
genes_in_common = [genes_in_common[ii] for ii in random_genes]

rnadata = rnadata[:,genes_in_common].copy()
tndata = tndata[:,genes_in_common].copy()
# Out:
# /usr/local/lib/python3.8/site-packages/anndata/_core/anndata.py:120: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %% [markdown]
# ### Sample QC

# %% [markdown]
# ### Gene QC

# %% [markdown]
# ### Sample and Gene Filtering

# %% [markdown]
# ### Batch effect removal

# %%
# sc.pp.combat(tndata, key='BioReplicate', covariates=['condition','TimePoint'], inplace=True)

# %% [markdown]
# ### Weighted Gene Co-expression Network
# Question: How should we incorporate multiple experimental conditions? Separate graphs for each?

# %% [markdown]
# We define the adjacency matrix as:
#
# $A_{ij} = \mathrm{corr}(g_i,g_j)^\beta $
#
# Here $\beta$ is a soft thresholding parameter to transform the Pearson correlations between gene $i$ and gene $j$ into a directed edge.
#
# Note that by construction, $A$ already contains self-loops. Don't add another self-loop during training, a typical procedure when training graph convolutional networks.

# %%
beta = 37 # This should be an even number to retain negative weights

if beta % 2 == 0: 
    print('Warning: beta was chosen to be an even integer which is not allowed. please set an odd value. \n The adjacency matrix is not defined.')
else: 
    cor = np.corrcoef(rnadata[rnadata.obs.condition.isin(['NC'])].X.T)
    A = cor ** beta
    A[np.abs(A) <= 10e-4] = 0.0

# %%
plt.figure(figsize=(8,6))
sns.heatmap(A,cmap='magma')
plt.show()

# %% [markdown]
# ### Graph edges: `data.edge_index` of shape `[2, num_edges]`

# %%
adj = torch.tensor(A,dtype=torch.float32)
edge_index = adj.nonzero().t().contiguous()
edge_index.shape
# Out:
# torch.Size([2, 8448])

# %%
edge_index
# Out:
# tensor([[  0,   0,   0,  ..., 249, 249, 249],
#         [  0,   2,   5,  ..., 235, 240, 249]])

# %% [markdown]
# ### Graph edge weights: `data.edge_weight` of shape `[num_edges]`

# %%
row1, row2 = edge_index
edge_weight = adj[row1, row2]

# %% [markdown]
# ### Node feature matrix: `data.x` of shape  `[num_nodes x num_node_features]`
# Using condition `NC` at the moment. Still thinking of how to incorporate all the conditions into the node prediction task. What would be useful?

# %%
x = torch.tensor(tndata[tndata.obs.condition.isin(['NC'])].X.copy().T, dtype=torch.float32)
x_train = x[:,0:7] # BioReplicate 1
x_test = x[:,7:] # BioReplicate 2

# %% [markdown]
# ### Graph data class

# %%
# data = Data(x=x_train, edge_index=edge_index, num_nodes=len(x), edge_weight=edge_weight)
data = Data(x=x, edge_index=edge_index, num_nodes=len(x), edge_weight=edge_weight)

# %% [markdown]
# ### Node targets: `data.y`
# As of now, the targets are one-hots corresponding to which gene was knocked down. Though there may be some other more reasonable approach for formulating the targets

# %%
a = np.array([ii for ii in range(len(x))])
y = np.zeros((a.size, a.max() + 1))
y[np.arange(a.size), a] = 1
y = y.transpose() # don't actually need this 
# y = np.arange(0,data.num_nodes)/(data.num_nodes-1)

# %%
data.y = torch.tensor(y,dtype=torch.float32)

# %% [markdown]
# ### Model architecture

# %% [markdown]
# EDGE WEIGHTS CAUSE nans in network output. why?

# %%
class Net(torch.nn.Module):
    def __init__(self):
        super().__init__()
        num_classes = data.num_nodes
#         num_classes = 1
        self.conv1 = SGConv(data.num_features, num_classes, K=2, add_self_loops=False, 
                            cached=False) # cached->what does this do, how does it relate to semi-supervision?
# edge_weight=data.edge_weight,
    def forward(self):
        x, edge_index, edge_weight = data.x, data.edge_index, data.edge_weight
        x = self.conv1(x, edge_index) # , edge_weight
        
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model, data = Net().to(device), data.to(device)

torch.manual_seed(100)

optimizer = torch.optim.Adam(model.parameters(), lr=0.025, weight_decay=0.001)
# optimizer = torch.optim.SGD(model.parameters(), lr=0.15, momentum=0.0, dampening=0.0, weight_decay=0.0)
scheduler = ExponentialLR(optimizer, gamma=0.975)
# criterion = nn.CrossEntropyLoss() # computes softmax and then the cross entropy
# criterion = nn.MSELoss()
# criterion = nn.KLDivLoss()

# %% [markdown]
# ### Model training

# %% [markdown]
# NEED TO CHECK THAT THE DIMENSIONS OF THE DATA GOING IN ARE CORRECT WITH WHICHEVER WAY PYTORCH IS DOING MATMUL

# %%
train_acc = []
for ii, epoch in enumerate(range(1, 1001)):
    model.train(True) # for gradient tracking 
    
    optimizer.zero_grad()
    yhat = model()
    loss = criterion(yhat, data.y)
    loss.backward()
    optimizer.step()
    scheduler.step()
    
    model.train(False) # don't need to track gradients for metrics
#     acc = np.linalg.norm(yhat.detach() - y)
#     train_acc.append(acc)
    corrects = (yhat.argmax(dim=1) == data.y.argmax(dim=1))
    train_acc.append( (corrects.sum()/data.y.size(1)).item() )
    print(f'Epoch: {epoch:03d}, Train: {train_acc[ii]:.4f}')
    
plt.plot(train_acc)
# Out:
# Epoch: 001, Train: 0.0000
# Epoch: 002, Train: 0.0040
# Epoch: 003, Train: 0.0080
# Epoch: 004, Train: 0.0200
# Epoch: 005, Train: 0.0320
# Epoch: 006, Train: 0.0320
# Epoch: 007, Train: 0.0440
# Epoch: 008, Train: 0.0520
# Epoch: 009, Train: 0.0480
# Epoch: 010, Train: 0.0640
# Epoch: 011, Train: 0.0680
# Epoch: 012, Train: 0.0720
# Epoch: 013, Train: 0.0760
# Epoch: 014, Train: 0.0800
# Epoch: 015, Train: 0.0800
# Epoch: 016, Train: 0.0840
# Epoch: 017, Train: 0.0840
# Epoch: 018, Train: 0.1000
# Epoch: 019, Train: 0.0960
# Epoch: 020, Train: 0.0960
# Epoch: 021, Train: 0.0920
# Epoch: 022, Train: 0.0880
# Epoch: 023, Train: 0.0960
# Epoch: 024, Train: 0.1000
# Epoch: 025, Train: 0.1000
# Epoch: 026, Train: 0.0960
# Epoch: 027, Train: 0.0920
# Epoch: 028, Train: 0.0880
# Epoch: 029, Train: 0.0840
# Epoch: 030, Train: 0.0960
# Epoch: 031, Train: 0.0920
# Epoch: 032, Train: 0.0920
# Epoch: 033, Train: 0.1000
# Epoch: 034, Train: 0.0880
# Epoch: 035, Train: 0.0920
# Epoch: 036, Train: 0.0880
# Epoch: 037, Train: 0.0880
# Epoch: 038, Train: 0.0880
# Epoch: 039, Train: 0.0880
# Epoch: 040, Train: 0.0920
# Epoch: 041, Train: 0.0920
# Epoch: 042, Train: 0.0880
# Epoch: 043, Train: 0.0840
# Epoch: 044, Train: 0.0840
# Epoch: 045, Train: 0.0880
# Epoch: 046, Train: 0.0880
# Epoch: 047, Train: 0.0920
# Epoch: 048, Train: 0.0920
# Epoch: 049, Train: 0.0920
# Epoch: 050, Train: 0.0880
# Epoch: 051, Train: 0.0840
# Epoch: 052, Train: 0.0840
# Epoch: 053, Train: 0.0800
# Epoch: 054, Train: 0.0760
# Epoch: 055, Train: 0.0760
# Epoch: 056, Train: 0.0760
# Epoch: 057, Train: 0.0760
# Epoch: 058, Train: 0.0720
# Epoch: 059, Train: 0.0720
# Epoch: 060, Train: 0.0720
# Epoch: 061, Train: 0.0720
# Epoch: 062, Train: 0.0720
# Epoch: 063, Train: 0.0720
# Epoch: 064, Train: 0.0720
# Epoch: 065, Train: 0.0720
# Epoch: 066, Train: 0.0680
# Epoch: 067, Train: 0.0680
# Epoch: 068, Train: 0.0680
# Epoch: 069, Train: 0.0680
# Epoch: 070, Train: 0.0680
# Epoch: 071, Train: 0.0680
# Epoch: 072, Train: 0.0680
# Epoch: 073, Train: 0.0680
# Epoch: 074, Train: 0.0680
# Epoch: 075, Train: 0.0680
# Epoch: 076, Train: 0.0720
# Epoch: 077, Train: 0.0720
# Epoch: 078, Train: 0.0720
# Epoch: 079, Train: 0.0720
# Epoch: 080, Train: 0.0720
# Epoch: 081, Train: 0.0720
# Epoch: 082, Train: 0.0720
# Epoch: 083, Train: 0.0720
# Epoch: 084, Train: 0.0720
# Epoch: 085, Train: 0.0720
# Epoch: 086, Train: 0.0720
# Epoch: 087, Train: 0.0720
# Epoch: 088, Train: 0.0720
# Epoch: 089, Train: 0.0720
# Epoch: 090, Train: 0.0720
# Epoch: 091, Train: 0.0720
# Epoch: 092, Train: 0.0720
# Epoch: 093, Train: 0.0720
# Epoch: 094, Train: 0.0720
# Epoch: 095, Train: 0.0720
# Epoch: 096, Train: 0.0720
# Epoch: 097, Train: 0.0720
# Epoch: 098, Train: 0.0720
# Epoch: 099, Train: 0.0720
# Epoch: 100, Train: 0.0720
# Epoch: 101, Train: 0.0720
# Epoch: 102, Train: 0.0720
# Epoch: 103, Train: 0.0720
# Epoch: 104, Train: 0.0760
# Epoch: 105, Train: 0.0760
# Epoch: 106, Train: 0.0760
# Epoch: 107, Train: 0.0760
# Epoch: 108, Train: 0.0760
# Epoch: 109, Train: 0.0760
# Epoch: 110, Train: 0.0760
# Epoch: 111, Train: 0.0760
# Epoch: 112, Train: 0.0760
# Epoch: 113, Train: 0.0760
# Epoch: 114, Train: 0.0760
# Epoch: 115, Train: 0.0760
# Epoch: 116, Train: 0.0760
# Epoch: 117, Train: 0.0760
# Epoch: 118, Train: 0.0760
# Epoch: 119, Train: 0.0760
# Epoch: 120, Train: 0.0760
# Epoch: 121, Train: 0.0720
# Epoch: 122, Train: 0.0720
# Epoch: 123, Train: 0.0720
# Epoch: 124, Train: 0.0720
# Epoch: 125, Train: 0.0720
# Epoch: 126, Train: 0.0720
# Epoch: 127, Train: 0.0720
# Epoch: 128, Train: 0.0720
# Epoch: 129, Train: 0.0720
# Epoch: 130, Train: 0.0720
# Epoch: 131, Train: 0.0720
# Epoch: 132, Train: 0.0720
# Epoch: 133, Train: 0.0720
# Epoch: 134, Train: 0.0720
# Epoch: 135, Train: 0.0720
# Epoch: 136, Train: 0.0720
# Epoch: 137, Train: 0.0720
# Epoch: 138, Train: 0.0720
# Epoch: 139, Train: 0.0720
# Epoch: 140, Train: 0.0720
# Epoch: 141, Train: 0.0720
# Epoch: 142, Train: 0.0720
# Epoch: 143, Train: 0.0720
# Epoch: 144, Train: 0.0720
# Epoch: 145, Train: 0.0720
# Epoch: 146, Train: 0.0720
# Epoch: 147, Train: 0.0720
# Epoch: 148, Train: 0.0720
# Epoch: 149, Train: 0.0720
# Epoch: 150, Train: 0.0720
# Epoch: 151, Train: 0.0720
# Epoch: 152, Train: 0.0720
# Epoch: 153, Train: 0.0720
# Epoch: 154, Train: 0.0720
# Epoch: 155, Train: 0.0720
# Epoch: 156, Train: 0.0720
# Epoch: 157, Train: 0.0720
# Epoch: 158, Train: 0.0720
# Epoch: 159, Train: 0.0720
# Epoch: 160, Train: 0.0720
# Epoch: 161, Train: 0.0720
# Epoch: 162, Train: 0.0720
# Epoch: 163, Train: 0.0720
# Epoch: 164, Train: 0.0680
# Epoch: 165, Train: 0.0680
# Epoch: 166, Train: 0.0680
# Epoch: 167, Train: 0.0680
# Epoch: 168, Train: 0.0680
# Epoch: 169, Train: 0.0680
# Epoch: 170, Train: 0.0680
# Epoch: 171, Train: 0.0680
# Epoch: 172, Train: 0.0680
# Epoch: 173, Train: 0.0680
# Epoch: 174, Train: 0.0680
# Epoch: 175, Train: 0.0680
# Epoch: 176, Train: 0.0680
# Epoch: 177, Train: 0.0680
# Epoch: 178, Train: 0.0680
# Epoch: 179, Train: 0.0680
# Epoch: 180, Train: 0.0680
# Epoch: 181, Train: 0.0680
# Epoch: 182, Train: 0.0680
# Epoch: 183, Train: 0.0680
# Epoch: 184, Train: 0.0680
# Epoch: 185, Train: 0.0680
# Epoch: 186, Train: 0.0680
# Epoch: 187, Train: 0.0680
# Epoch: 188, Train: 0.0680
# Epoch: 189, Train: 0.0680
# Epoch: 190, Train: 0.0680
# Epoch: 191, Train: 0.0680
# Epoch: 192, Train: 0.0680
# Epoch: 193, Train: 0.0680
# Epoch: 194, Train: 0.0680
# Epoch: 195, Train: 0.0680
# Epoch: 196, Train: 0.0680
# Epoch: 197, Train: 0.0680
# Epoch: 198, Train: 0.0680
# Epoch: 199, Train: 0.0680
# Epoch: 200, Train: 0.0680
# Epoch: 201, Train: 0.0680
# Epoch: 202, Train: 0.0680
# Epoch: 203, Train: 0.0680
# Epoch: 204, Train: 0.0680
# Epoch: 205, Train: 0.0680
# Epoch: 206, Train: 0.0680
# Epoch: 207, Train: 0.0680
# Epoch: 208, Train: 0.0680
# Epoch: 209, Train: 0.0680
# Epoch: 210, Train: 0.0680
# Epoch: 211, Train: 0.0680
# Epoch: 212, Train: 0.0680
# Epoch: 213, Train: 0.0680
# Epoch: 214, Train: 0.0680
# Epoch: 215, Train: 0.0680
# Epoch: 216, Train: 0.0680
# Epoch: 217, Train: 0.0680
# Epoch: 218, Train: 0.0680
# Epoch: 219, Train: 0.0680
# Epoch: 220, Train: 0.0680
# Epoch: 221, Train: 0.0680
# Epoch: 222, Train: 0.0680
# Epoch: 223, Train: 0.0680
# Epoch: 224, Train: 0.0680
# Epoch: 225, Train: 0.0680
# Epoch: 226, Train: 0.0680
# Epoch: 227, Train: 0.0680
# Epoch: 228, Train: 0.0680
# Epoch: 229, Train: 0.0680
# Epoch: 230, Train: 0.0680
# Epoch: 231, Train: 0.0680
# Epoch: 232, Train: 0.0680
# Epoch: 233, Train: 0.0680
# Epoch: 234, Train: 0.0680
# Epoch: 235, Train: 0.0680
# Epoch: 236, Train: 0.0680
# Epoch: 237, Train: 0.0680
# Epoch: 238, Train: 0.0680
# Epoch: 239, Train: 0.0680
# Epoch: 240, Train: 0.0680
# Epoch: 241, Train: 0.0680
# Epoch: 242, Train: 0.0680
# Epoch: 243, Train: 0.0680
# Epoch: 244, Train: 0.0680
# Epoch: 245, Train: 0.0680
# Epoch: 246, Train: 0.0680
# Epoch: 247, Train: 0.0680
# Epoch: 248, Train: 0.0680
# Epoch: 249, Train: 0.0680
# Epoch: 250, Train: 0.0680
# Epoch: 251, Train: 0.0680
# Epoch: 252, Train: 0.0680
# Epoch: 253, Train: 0.0680
# Epoch: 254, Train: 0.0680
# Epoch: 255, Train: 0.0680
# Epoch: 256, Train: 0.0680
# Epoch: 257, Train: 0.0680
# Epoch: 258, Train: 0.0680
# Epoch: 259, Train: 0.0680
# Epoch: 260, Train: 0.0680
# Epoch: 261, Train: 0.0680
# Epoch: 262, Train: 0.0680
# Epoch: 263, Train: 0.0680
# Epoch: 264, Train: 0.0680
# Epoch: 265, Train: 0.0680
# Epoch: 266, Train: 0.0680
# Epoch: 267, Train: 0.0680
# Epoch: 268, Train: 0.0680
# Epoch: 269, Train: 0.0680
# Epoch: 270, Train: 0.0680
# Epoch: 271, Train: 0.0680
# Epoch: 272, Train: 0.0680
# Epoch: 273, Train: 0.0680
# Epoch: 274, Train: 0.0680
# Epoch: 275, Train: 0.0680
# Epoch: 276, Train: 0.0680
# Epoch: 277, Train: 0.0680
# Epoch: 278, Train: 0.0680
# Epoch: 279, Train: 0.0680
# Epoch: 280, Train: 0.0680
# Epoch: 281, Train: 0.0680
# Epoch: 282, Train: 0.0680
# Epoch: 283, Train: 0.0680
# Epoch: 284, Train: 0.0680
# Epoch: 285, Train: 0.0680
# Epoch: 286, Train: 0.0680
# Epoch: 287, Train: 0.0680
# Epoch: 288, Train: 0.0680
# Epoch: 289, Train: 0.0680
# Epoch: 290, Train: 0.0680
# Epoch: 291, Train: 0.0680
# Epoch: 292, Train: 0.0680
# Epoch: 293, Train: 0.0680
# Epoch: 294, Train: 0.0680
# Epoch: 295, Train: 0.0680
# Epoch: 296, Train: 0.0680
# Epoch: 297, Train: 0.0680
# Epoch: 298, Train: 0.0680
# Epoch: 299, Train: 0.0680
# Epoch: 300, Train: 0.0680
# Epoch: 301, Train: 0.0680
# Epoch: 302, Train: 0.0680
# Epoch: 303, Train: 0.0680
# Epoch: 304, Train: 0.0680
# Epoch: 305, Train: 0.0680
# Epoch: 306, Train: 0.0680
# Epoch: 307, Train: 0.0680
# Epoch: 308, Train: 0.0680
# Epoch: 309, Train: 0.0680
# Epoch: 310, Train: 0.0680
# Epoch: 311, Train: 0.0680
# Epoch: 312, Train: 0.0680
# Epoch: 313, Train: 0.0680
# Epoch: 314, Train: 0.0680
# Epoch: 315, Train: 0.0680
# Epoch: 316, Train: 0.0680
# Epoch: 317, Train: 0.0680
# Epoch: 318, Train: 0.0680
# Epoch: 319, Train: 0.0680
# Epoch: 320, Train: 0.0680
# Epoch: 321, Train: 0.0680
# Epoch: 322, Train: 0.0680
# Epoch: 323, Train: 0.0680
# Epoch: 324, Train: 0.0680
# Epoch: 325, Train: 0.0680
# Epoch: 326, Train: 0.0680
# Epoch: 327, Train: 0.0680
# Epoch: 328, Train: 0.0680
# Epoch: 329, Train: 0.0680
# Epoch: 330, Train: 0.0680
# Epoch: 331, Train: 0.0680
# Epoch: 332, Train: 0.0680
# Epoch: 333, Train: 0.0680
# Epoch: 334, Train: 0.0680
# Epoch: 335, Train: 0.0680
# Epoch: 336, Train: 0.0680
# Epoch: 337, Train: 0.0680
# Epoch: 338, Train: 0.0680
# Epoch: 339, Train: 0.0680
# Epoch: 340, Train: 0.0680
# Epoch: 341, Train: 0.0680
# Epoch: 342, Train: 0.0680
# Epoch: 343, Train: 0.0680
# Epoch: 344, Train: 0.0680
# Epoch: 345, Train: 0.0680
# Epoch: 346, Train: 0.0680
# Epoch: 347, Train: 0.0680
# Epoch: 348, Train: 0.0680
# Epoch: 349, Train: 0.0680
# Epoch: 350, Train: 0.0680
# Epoch: 351, Train: 0.0680
# Epoch: 352, Train: 0.0680
# Epoch: 353, Train: 0.0680
# Epoch: 354, Train: 0.0680
# Epoch: 355, Train: 0.0680
# Epoch: 356, Train: 0.0680
# Epoch: 357, Train: 0.0680
# Epoch: 358, Train: 0.0680
# Epoch: 359, Train: 0.0680
# Epoch: 360, Train: 0.0680
# Epoch: 361, Train: 0.0680
# Epoch: 362, Train: 0.0680
# Epoch: 363, Train: 0.0680
# Epoch: 364, Train: 0.0680
# Epoch: 365, Train: 0.0680
# Epoch: 366, Train: 0.0680
# Epoch: 367, Train: 0.0680
# Epoch: 368, Train: 0.0680
# Epoch: 369, Train: 0.0680
# Epoch: 370, Train: 0.0680
# Epoch: 371, Train: 0.0680
# Epoch: 372, Train: 0.0680
# Epoch: 373, Train: 0.0680
# Epoch: 374, Train: 0.0680
# Epoch: 375, Train: 0.0680
# Epoch: 376, Train: 0.0680
# Epoch: 377, Train: 0.0680
# Epoch: 378, Train: 0.0680
# Epoch: 379, Train: 0.0680
# Epoch: 380, Train: 0.0680
# Epoch: 381, Train: 0.0680
# Epoch: 382, Train: 0.0680
# Epoch: 383, Train: 0.0680
# Epoch: 384, Train: 0.0680
# Epoch: 385, Train: 0.0680
# Epoch: 386, Train: 0.0680
# Epoch: 387, Train: 0.0680
# Epoch: 388, Train: 0.0680
# Epoch: 389, Train: 0.0680
# Epoch: 390, Train: 0.0680
# Epoch: 391, Train: 0.0680
# Epoch: 392, Train: 0.0680
# Epoch: 393, Train: 0.0680
# Epoch: 394, Train: 0.0680
# Epoch: 395, Train: 0.0680
# Epoch: 396, Train: 0.0680
# Epoch: 397, Train: 0.0680
# Epoch: 398, Train: 0.0680
# Epoch: 399, Train: 0.0680
# Epoch: 400, Train: 0.0680
# Epoch: 401, Train: 0.0680
# Epoch: 402, Train: 0.0680
# Epoch: 403, Train: 0.0680
# Epoch: 404, Train: 0.0680
# Epoch: 405, Train: 0.0680
# Epoch: 406, Train: 0.0680
# Epoch: 407, Train: 0.0680
# Epoch: 408, Train: 0.0680
# Epoch: 409, Train: 0.0680
# Epoch: 410, Train: 0.0680
# Epoch: 411, Train: 0.0680
# Epoch: 412, Train: 0.0680
# Epoch: 413, Train: 0.0680
# Epoch: 414, Train: 0.0680
# Epoch: 415, Train: 0.0680
# Epoch: 416, Train: 0.0680
# Epoch: 417, Train: 0.0680
# Epoch: 418, Train: 0.0680
# Epoch: 419, Train: 0.0680
# Epoch: 420, Train: 0.0680
# Epoch: 421, Train: 0.0680
# Epoch: 422, Train: 0.0680
# Epoch: 423, Train: 0.0680
# Epoch: 424, Train: 0.0680
# Epoch: 425, Train: 0.0680
# Epoch: 426, Train: 0.0680
# Epoch: 427, Train: 0.0680
# Epoch: 428, Train: 0.0680
# Epoch: 429, Train: 0.0680
# Epoch: 430, Train: 0.0680
# Epoch: 431, Train: 0.0680
# Epoch: 432, Train: 0.0680
# Epoch: 433, Train: 0.0680
# Epoch: 434, Train: 0.0680
# Epoch: 435, Train: 0.0680
# Epoch: 436, Train: 0.0680
# Epoch: 437, Train: 0.0680
# Epoch: 438, Train: 0.0680
# Epoch: 439, Train: 0.0680
# Epoch: 440, Train: 0.0680
# Epoch: 441, Train: 0.0680
# Epoch: 442, Train: 0.0680
# Epoch: 443, Train: 0.0680
# Epoch: 444, Train: 0.0680
# Epoch: 445, Train: 0.0680
# Epoch: 446, Train: 0.0680
# Epoch: 447, Train: 0.0680
# Epoch: 448, Train: 0.0680
# Epoch: 449, Train: 0.0680
# Epoch: 450, Train: 0.0680
# Epoch: 451, Train: 0.0680
# Epoch: 452, Train: 0.0680
# Epoch: 453, Train: 0.0680
# Epoch: 454, Train: 0.0680
# Epoch: 455, Train: 0.0680
# Epoch: 456, Train: 0.0680
# Epoch: 457, Train: 0.0680
# Epoch: 458, Train: 0.0680
# Epoch: 459, Train: 0.0680
# Epoch: 460, Train: 0.0680
# Epoch: 461, Train: 0.0680
# Epoch: 462, Train: 0.0680
# Epoch: 463, Train: 0.0680
# Epoch: 464, Train: 0.0680
# Epoch: 465, Train: 0.0680
# Epoch: 466, Train: 0.0680
# Epoch: 467, Train: 0.0680
# Epoch: 468, Train: 0.0680
# Epoch: 469, Train: 0.0680
# Epoch: 470, Train: 0.0680
# Epoch: 471, Train: 0.0680
# Epoch: 472, Train: 0.0680
# Epoch: 473, Train: 0.0680
# Epoch: 474, Train: 0.0680
# Epoch: 475, Train: 0.0680
# Epoch: 476, Train: 0.0680
# Epoch: 477, Train: 0.0680
# Epoch: 478, Train: 0.0680
# Epoch: 479, Train: 0.0680
# Epoch: 480, Train: 0.0680
# Epoch: 481, Train: 0.0680
# Epoch: 482, Train: 0.0680
# Epoch: 483, Train: 0.0680
# Epoch: 484, Train: 0.0680
# Epoch: 485, Train: 0.0680
# Epoch: 486, Train: 0.0680
# Epoch: 487, Train: 0.0680
# Epoch: 488, Train: 0.0680
# Epoch: 489, Train: 0.0680
# Epoch: 490, Train: 0.0680
# Epoch: 491, Train: 0.0680
# Epoch: 492, Train: 0.0680
# Epoch: 493, Train: 0.0680
# Epoch: 494, Train: 0.0680
# Epoch: 495, Train: 0.0680
# Epoch: 496, Train: 0.0680
# Epoch: 497, Train: 0.0680
# Epoch: 498, Train: 0.0680
# Epoch: 499, Train: 0.0680
# Epoch: 500, Train: 0.0680
# Epoch: 501, Train: 0.0680
# Epoch: 502, Train: 0.0680
# Epoch: 503, Train: 0.0680
# Epoch: 504, Train: 0.0680
# Epoch: 505, Train: 0.0680
# Epoch: 506, Train: 0.0680
# Epoch: 507, Train: 0.0680
# Epoch: 508, Train: 0.0680
# Epoch: 509, Train: 0.0680
# Epoch: 510, Train: 0.0680
# Epoch: 511, Train: 0.0680
# Epoch: 512, Train: 0.0680
# Epoch: 513, Train: 0.0680
# Epoch: 514, Train: 0.0680
# Epoch: 515, Train: 0.0680
# Epoch: 516, Train: 0.0680
# Epoch: 517, Train: 0.0680
# Epoch: 518, Train: 0.0680
# Epoch: 519, Train: 0.0680
# Epoch: 520, Train: 0.0680
# Epoch: 521, Train: 0.0680
# Epoch: 522, Train: 0.0680
# Epoch: 523, Train: 0.0680
# Epoch: 524, Train: 0.0680
# Epoch: 525, Train: 0.0680
# Epoch: 526, Train: 0.0680
# Epoch: 527, Train: 0.0680
# Epoch: 528, Train: 0.0680
# Epoch: 529, Train: 0.0680
# Epoch: 530, Train: 0.0680
# Epoch: 531, Train: 0.0680
# Epoch: 532, Train: 0.0680
# Epoch: 533, Train: 0.0680
# Epoch: 534, Train: 0.0680
# Epoch: 535, Train: 0.0680
# Epoch: 536, Train: 0.0680
# Epoch: 537, Train: 0.0680
# Epoch: 538, Train: 0.0680
# Epoch: 539, Train: 0.0680
# Epoch: 540, Train: 0.0680
# Epoch: 541, Train: 0.0680
# Epoch: 542, Train: 0.0680
# Epoch: 543, Train: 0.0680
# Epoch: 544, Train: 0.0680
# Epoch: 545, Train: 0.0680
# Epoch: 546, Train: 0.0680
# Epoch: 547, Train: 0.0680
# Epoch: 548, Train: 0.0680
# Epoch: 549, Train: 0.0680
# Epoch: 550, Train: 0.0680
# Epoch: 551, Train: 0.0680
# Epoch: 552, Train: 0.0680
# Epoch: 553, Train: 0.0680
# Epoch: 554, Train: 0.0680
# Epoch: 555, Train: 0.0680
# Epoch: 556, Train: 0.0680
# Epoch: 557, Train: 0.0680
# Epoch: 558, Train: 0.0680
# Epoch: 559, Train: 0.0680
# Epoch: 560, Train: 0.0680
# Epoch: 561, Train: 0.0680
# Epoch: 562, Train: 0.0680
# Epoch: 563, Train: 0.0680
# Epoch: 564, Train: 0.0680
# Epoch: 565, Train: 0.0680
# Epoch: 566, Train: 0.0680
# Epoch: 567, Train: 0.0680
# Epoch: 568, Train: 0.0680
# Epoch: 569, Train: 0.0680
# Epoch: 570, Train: 0.0680
# Epoch: 571, Train: 0.0680
# Epoch: 572, Train: 0.0680
# Epoch: 573, Train: 0.0680
# Epoch: 574, Train: 0.0680
# Epoch: 575, Train: 0.0680
# Epoch: 576, Train: 0.0680
# Epoch: 577, Train: 0.0680
# Epoch: 578, Train: 0.0680
# Epoch: 579, Train: 0.0680
# Epoch: 580, Train: 0.0680
# Epoch: 581, Train: 0.0680
# Epoch: 582, Train: 0.0680
# Epoch: 583, Train: 0.0680
# Epoch: 584, Train: 0.0680
# Epoch: 585, Train: 0.0680
# Epoch: 586, Train: 0.0680
# Epoch: 587, Train: 0.0680
# Epoch: 588, Train: 0.0680
# Epoch: 589, Train: 0.0680
# Epoch: 590, Train: 0.0680
# Epoch: 591, Train: 0.0680
# Epoch: 592, Train: 0.0680
# Epoch: 593, Train: 0.0680
# Epoch: 594, Train: 0.0680
# Epoch: 595, Train: 0.0680
# Epoch: 596, Train: 0.0680
# Epoch: 597, Train: 0.0680
# Epoch: 598, Train: 0.0680
# Epoch: 599, Train: 0.0680
# Epoch: 600, Train: 0.0680
# Epoch: 601, Train: 0.0680
# Epoch: 602, Train: 0.0680
# Epoch: 603, Train: 0.0680
# Epoch: 604, Train: 0.0680
# Epoch: 605, Train: 0.0680
# Epoch: 606, Train: 0.0680
# Epoch: 607, Train: 0.0680
# Epoch: 608, Train: 0.0680
# Epoch: 609, Train: 0.0680
# Epoch: 610, Train: 0.0680
# Epoch: 611, Train: 0.0680
# Epoch: 612, Train: 0.0680
# Epoch: 613, Train: 0.0680
# Epoch: 614, Train: 0.0680
# Epoch: 615, Train: 0.0680
# Epoch: 616, Train: 0.0680
# Epoch: 617, Train: 0.0680
# Epoch: 618, Train: 0.0680
# Epoch: 619, Train: 0.0680
# Epoch: 620, Train: 0.0680
# Epoch: 621, Train: 0.0680
# Epoch: 622, Train: 0.0680
# Epoch: 623, Train: 0.0680
# Epoch: 624, Train: 0.0680
# Epoch: 625, Train: 0.0680
# Epoch: 626, Train: 0.0680
# Epoch: 627, Train: 0.0680
# Epoch: 628, Train: 0.0680
# Epoch: 629, Train: 0.0680
# Epoch: 630, Train: 0.0680
# Epoch: 631, Train: 0.0680
# Epoch: 632, Train: 0.0680
# Epoch: 633, Train: 0.0680
# Epoch: 634, Train: 0.0680
# Epoch: 635, Train: 0.0680
# Epoch: 636, Train: 0.0680
# Epoch: 637, Train: 0.0680
# Epoch: 638, Train: 0.0680
# Epoch: 639, Train: 0.0680
# Epoch: 640, Train: 0.0680
# Epoch: 641, Train: 0.0680
# Epoch: 642, Train: 0.0680
# Epoch: 643, Train: 0.0680
# Epoch: 644, Train: 0.0680
# Epoch: 645, Train: 0.0680
# Epoch: 646, Train: 0.0680
# Epoch: 647, Train: 0.0680
# Epoch: 648, Train: 0.0680
# Epoch: 649, Train: 0.0680
# Epoch: 650, Train: 0.0680
# Epoch: 651, Train: 0.0680
# Epoch: 652, Train: 0.0680
# Epoch: 653, Train: 0.0680
# Epoch: 654, Train: 0.0680
# Epoch: 655, Train: 0.0680
# Epoch: 656, Train: 0.0680
# Epoch: 657, Train: 0.0680
# Epoch: 658, Train: 0.0680
# Epoch: 659, Train: 0.0680
# Epoch: 660, Train: 0.0680
# Epoch: 661, Train: 0.0680
# Epoch: 662, Train: 0.0680
# Epoch: 663, Train: 0.0680
# Epoch: 664, Train: 0.0680
# Epoch: 665, Train: 0.0680
# Epoch: 666, Train: 0.0680
# Epoch: 667, Train: 0.0680
# Epoch: 668, Train: 0.0680
# Epoch: 669, Train: 0.0680
# Epoch: 670, Train: 0.0680
# Epoch: 671, Train: 0.0680
# Epoch: 672, Train: 0.0680
# Epoch: 673, Train: 0.0680
# Epoch: 674, Train: 0.0680
# Epoch: 675, Train: 0.0680
# Epoch: 676, Train: 0.0680
# Epoch: 677, Train: 0.0680
# Epoch: 678, Train: 0.0680
# Epoch: 679, Train: 0.0680
# Epoch: 680, Train: 0.0680
# Epoch: 681, Train: 0.0680
# Epoch: 682, Train: 0.0680
# Epoch: 683, Train: 0.0680
# Epoch: 684, Train: 0.0680
# Epoch: 685, Train: 0.0680
# Epoch: 686, Train: 0.0680
# Epoch: 687, Train: 0.0680
# Epoch: 688, Train: 0.0680
# Epoch: 689, Train: 0.0680
# Epoch: 690, Train: 0.0680
# Epoch: 691, Train: 0.0680
# Epoch: 692, Train: 0.0680
# Epoch: 693, Train: 0.0680
# Epoch: 694, Train: 0.0680
# Epoch: 695, Train: 0.0680
# Epoch: 696, Train: 0.0680
# Epoch: 697, Train: 0.0680
# Epoch: 698, Train: 0.0680
# Epoch: 699, Train: 0.0680
# Epoch: 700, Train: 0.0680
# Epoch: 701, Train: 0.0680
# Epoch: 702, Train: 0.0680
# Epoch: 703, Train: 0.0680
# Epoch: 704, Train: 0.0680
# Epoch: 705, Train: 0.0680
# Epoch: 706, Train: 0.0680
# Epoch: 707, Train: 0.0680
# Epoch: 708, Train: 0.0680
# Epoch: 709, Train: 0.0680
# Epoch: 710, Train: 0.0680
# Epoch: 711, Train: 0.0680
# Epoch: 712, Train: 0.0680
# Epoch: 713, Train: 0.0680
# Epoch: 714, Train: 0.0680
# Epoch: 715, Train: 0.0680
# Epoch: 716, Train: 0.0680
# Epoch: 717, Train: 0.0680
# Epoch: 718, Train: 0.0680
# Epoch: 719, Train: 0.0680
# Epoch: 720, Train: 0.0680
# Epoch: 721, Train: 0.0680
# Epoch: 722, Train: 0.0680
# Epoch: 723, Train: 0.0680
# Epoch: 724, Train: 0.0680
# Epoch: 725, Train: 0.0680
# Epoch: 726, Train: 0.0680
# Epoch: 727, Train: 0.0680
# Epoch: 728, Train: 0.0680
# Epoch: 729, Train: 0.0680
# Epoch: 730, Train: 0.0680
# Epoch: 731, Train: 0.0680
# Epoch: 732, Train: 0.0680
# Epoch: 733, Train: 0.0680
# Epoch: 734, Train: 0.0680
# Epoch: 735, Train: 0.0680
# Epoch: 736, Train: 0.0680
# Epoch: 737, Train: 0.0680
# Epoch: 738, Train: 0.0680
# Epoch: 739, Train: 0.0680
# Epoch: 740, Train: 0.0680
# Epoch: 741, Train: 0.0680
# Epoch: 742, Train: 0.0680
# Epoch: 743, Train: 0.0680
# Epoch: 744, Train: 0.0680
# Epoch: 745, Train: 0.0680
# Epoch: 746, Train: 0.0680
# Epoch: 747, Train: 0.0680
# Epoch: 748, Train: 0.0680
# Epoch: 749, Train: 0.0680
# Epoch: 750, Train: 0.0680
# Epoch: 751, Train: 0.0680
# Epoch: 752, Train: 0.0680
# Epoch: 753, Train: 0.0680
# Epoch: 754, Train: 0.0680
# Epoch: 755, Train: 0.0680
# Epoch: 756, Train: 0.0680
# Epoch: 757, Train: 0.0680
# Epoch: 758, Train: 0.0680
# Epoch: 759, Train: 0.0680
# Epoch: 760, Train: 0.0680
# Epoch: 761, Train: 0.0680
# Epoch: 762, Train: 0.0680
# Epoch: 763, Train: 0.0680
# Epoch: 764, Train: 0.0680
# Epoch: 765, Train: 0.0680
# Epoch: 766, Train: 0.0680
# Epoch: 767, Train: 0.0680
# Epoch: 768, Train: 0.0680
# Epoch: 769, Train: 0.0680
# Epoch: 770, Train: 0.0680
# Epoch: 771, Train: 0.0680
# Epoch: 772, Train: 0.0680
# Epoch: 773, Train: 0.0680
# Epoch: 774, Train: 0.0680
# Epoch: 775, Train: 0.0680
# Epoch: 776, Train: 0.0680
# Epoch: 777, Train: 0.0680
# Epoch: 778, Train: 0.0680
# Epoch: 779, Train: 0.0680
# Epoch: 780, Train: 0.0680
# Epoch: 781, Train: 0.0680
# Epoch: 782, Train: 0.0680
# Epoch: 783, Train: 0.0680
# Epoch: 784, Train: 0.0680
# Epoch: 785, Train: 0.0680
# Epoch: 786, Train: 0.0680
# Epoch: 787, Train: 0.0680
# Epoch: 788, Train: 0.0680
# Epoch: 789, Train: 0.0680
# Epoch: 790, Train: 0.0680
# Epoch: 791, Train: 0.0680
# Epoch: 792, Train: 0.0680
# Epoch: 793, Train: 0.0680
# Epoch: 794, Train: 0.0680
# Epoch: 795, Train: 0.0680
# Epoch: 796, Train: 0.0680
# Epoch: 797, Train: 0.0680
# Epoch: 798, Train: 0.0680
# Epoch: 799, Train: 0.0680
# Epoch: 800, Train: 0.0680
# Epoch: 801, Train: 0.0680
# Epoch: 802, Train: 0.0680
# Epoch: 803, Train: 0.0680
# Epoch: 804, Train: 0.0680
# Epoch: 805, Train: 0.0680
# Epoch: 806, Train: 0.0680
# Epoch: 807, Train: 0.0680
# Epoch: 808, Train: 0.0680
# Epoch: 809, Train: 0.0680
# Epoch: 810, Train: 0.0680
# Epoch: 811, Train: 0.0680
# Epoch: 812, Train: 0.0680
# Epoch: 813, Train: 0.0680
# Epoch: 814, Train: 0.0680
# Epoch: 815, Train: 0.0680
# Epoch: 816, Train: 0.0680
# Epoch: 817, Train: 0.0680
# Epoch: 818, Train: 0.0680
# Epoch: 819, Train: 0.0680
# Epoch: 820, Train: 0.0680
# Epoch: 821, Train: 0.0680
# Epoch: 822, Train: 0.0680
# Epoch: 823, Train: 0.0680
# Epoch: 824, Train: 0.0680
# Epoch: 825, Train: 0.0680
# Epoch: 826, Train: 0.0680
# Epoch: 827, Train: 0.0680
# Epoch: 828, Train: 0.0680
# Epoch: 829, Train: 0.0680
# Epoch: 830, Train: 0.0680
# Epoch: 831, Train: 0.0680
# Epoch: 832, Train: 0.0680
# Epoch: 833, Train: 0.0680
# Epoch: 834, Train: 0.0680
# Epoch: 835, Train: 0.0680
# Epoch: 836, Train: 0.0680
# Epoch: 837, Train: 0.0680
# Epoch: 838, Train: 0.0680
# Epoch: 839, Train: 0.0680
# Epoch: 840, Train: 0.0680
# Epoch: 841, Train: 0.0680
# Epoch: 842, Train: 0.0680
# Epoch: 843, Train: 0.0680
# Epoch: 844, Train: 0.0680
# Epoch: 845, Train: 0.0680
# Epoch: 846, Train: 0.0680
# Epoch: 847, Train: 0.0680
# Epoch: 848, Train: 0.0680
# Epoch: 849, Train: 0.0680
# Epoch: 850, Train: 0.0680
# Epoch: 851, Train: 0.0680
# Epoch: 852, Train: 0.0680
# Epoch: 853, Train: 0.0680
# Epoch: 854, Train: 0.0680
# Epoch: 855, Train: 0.0680
# Epoch: 856, Train: 0.0680
# Epoch: 857, Train: 0.0680
# Epoch: 858, Train: 0.0680
# Epoch: 859, Train: 0.0680
# Epoch: 860, Train: 0.0680
# Epoch: 861, Train: 0.0680
# Epoch: 862, Train: 0.0680
# Epoch: 863, Train: 0.0680
# Epoch: 864, Train: 0.0680
# Epoch: 865, Train: 0.0680
# Epoch: 866, Train: 0.0680
# Epoch: 867, Train: 0.0680
# Epoch: 868, Train: 0.0680
# Epoch: 869, Train: 0.0680
# Epoch: 870, Train: 0.0680
# Epoch: 871, Train: 0.0680
# Epoch: 872, Train: 0.0680
# Epoch: 873, Train: 0.0680
# Epoch: 874, Train: 0.0680
# Epoch: 875, Train: 0.0680
# Epoch: 876, Train: 0.0680
# Epoch: 877, Train: 0.0680
# Epoch: 878, Train: 0.0680
# Epoch: 879, Train: 0.0680
# Epoch: 880, Train: 0.0680
# Epoch: 881, Train: 0.0680
# Epoch: 882, Train: 0.0680
# Epoch: 883, Train: 0.0680
# Epoch: 884, Train: 0.0680
# Epoch: 885, Train: 0.0680
# Epoch: 886, Train: 0.0680
# Epoch: 887, Train: 0.0680
# Epoch: 888, Train: 0.0680
# Epoch: 889, Train: 0.0680
# Epoch: 890, Train: 0.0680
# Epoch: 891, Train: 0.0680
# Epoch: 892, Train: 0.0680
# Epoch: 893, Train: 0.0680
# Epoch: 894, Train: 0.0680
# Epoch: 895, Train: 0.0680
# Epoch: 896, Train: 0.0680
# Epoch: 897, Train: 0.0680
# Epoch: 898, Train: 0.0680
# Epoch: 899, Train: 0.0680
# Epoch: 900, Train: 0.0680
# Epoch: 901, Train: 0.0680
# Epoch: 902, Train: 0.0680
# Epoch: 903, Train: 0.0680
# Epoch: 904, Train: 0.0680
# Epoch: 905, Train: 0.0680
# Epoch: 906, Train: 0.0680
# Epoch: 907, Train: 0.0680
# Epoch: 908, Train: 0.0680
# Epoch: 909, Train: 0.0680
# Epoch: 910, Train: 0.0680
# Epoch: 911, Train: 0.0680
# Epoch: 912, Train: 0.0680
# Epoch: 913, Train: 0.0680
# Epoch: 914, Train: 0.0680
# Epoch: 915, Train: 0.0680
# Epoch: 916, Train: 0.0680
# Epoch: 917, Train: 0.0680
# Epoch: 918, Train: 0.0680
# Epoch: 919, Train: 0.0680
# Epoch: 920, Train: 0.0680
# Epoch: 921, Train: 0.0680
# Epoch: 922, Train: 0.0680
# Epoch: 923, Train: 0.0680
# Epoch: 924, Train: 0.0680
# Epoch: 925, Train: 0.0680
# Epoch: 926, Train: 0.0680
# Epoch: 927, Train: 0.0680
# Epoch: 928, Train: 0.0680
# Epoch: 929, Train: 0.0680
# Epoch: 930, Train: 0.0680
# Epoch: 931, Train: 0.0680
# Epoch: 932, Train: 0.0680
# Epoch: 933, Train: 0.0680
# Epoch: 934, Train: 0.0680
# Epoch: 935, Train: 0.0680
# Epoch: 936, Train: 0.0680
# Epoch: 937, Train: 0.0680
# Epoch: 938, Train: 0.0680
# Epoch: 939, Train: 0.0680
# Epoch: 940, Train: 0.0680
# Epoch: 941, Train: 0.0680
# Epoch: 942, Train: 0.0680
# Epoch: 943, Train: 0.0680
# Epoch: 944, Train: 0.0680
# Epoch: 945, Train: 0.0680
# Epoch: 946, Train: 0.0680
# Epoch: 947, Train: 0.0680
# Epoch: 948, Train: 0.0680
# Epoch: 949, Train: 0.0680
# Epoch: 950, Train: 0.0680
# Epoch: 951, Train: 0.0680
# Epoch: 952, Train: 0.0680
# Epoch: 953, Train: 0.0680
# Epoch: 954, Train: 0.0680
# Epoch: 955, Train: 0.0680
# Epoch: 956, Train: 0.0680
# Epoch: 957, Train: 0.0680
# Epoch: 958, Train: 0.0680
# Epoch: 959, Train: 0.0680
# Epoch: 960, Train: 0.0680
# Epoch: 961, Train: 0.0680
# Epoch: 962, Train: 0.0680
# Epoch: 963, Train: 0.0680
# Epoch: 964, Train: 0.0680
# Epoch: 965, Train: 0.0680
# Epoch: 966, Train: 0.0680
# Epoch: 967, Train: 0.0680
# Epoch: 968, Train: 0.0680
# Epoch: 969, Train: 0.0680
# Epoch: 970, Train: 0.0680
# Epoch: 971, Train: 0.0680
# Epoch: 972, Train: 0.0680
# Epoch: 973, Train: 0.0680
# Epoch: 974, Train: 0.0680
# Epoch: 975, Train: 0.0680
# Epoch: 976, Train: 0.0680
# Epoch: 977, Train: 0.0680
# Epoch: 978, Train: 0.0680
# Epoch: 979, Train: 0.0680
# Epoch: 980, Train: 0.0680
# Epoch: 981, Train: 0.0680
# Epoch: 982, Train: 0.0680
# Epoch: 983, Train: 0.0680
# Epoch: 984, Train: 0.0680
# Epoch: 985, Train: 0.0680
# Epoch: 986, Train: 0.0680
# Epoch: 987, Train: 0.0680
# Epoch: 988, Train: 0.0680
# Epoch: 989, Train: 0.0680
# Epoch: 990, Train: 0.0680
# Epoch: 991, Train: 0.0680
# Epoch: 992, Train: 0.0680
# Epoch: 993, Train: 0.0680
# Epoch: 994, Train: 0.0680
# Epoch: 995, Train: 0.0680
# Epoch: 996, Train: 0.0680
# Epoch: 997, Train: 0.0680
# Epoch: 998, Train: 0.0680
# Epoch: 999, Train: 0.0680
# Epoch: 1000, Train: 0.0680

# %%
np.where((yhat.argmax(dim=0) - data.y.argmax(dim=0)).detach() == 0)
# Out:
# (array([ 31, 157, 195]),)

# %%
yhat
# Out:
# tensor([[-0.2043, -0.0233,  0.1842,  ...,  0.0033, -0.2107,  0.0020],
#         [-0.2084,  0.0020,  0.1849,  ...,  0.0413, -0.2112, -0.0015],
#         [-0.2047, -0.0107,  0.1824,  ...,  0.0162, -0.2107,  0.0092],
#         ...,
#         [-0.1785, -0.0028,  0.1647,  ...,  0.0120, -0.1958,  0.0021],
#         [-0.2168, -0.0051,  0.1695,  ...,  0.0386, -0.2089,  0.0310],
#         [-0.2009, -0.0034,  0.1854,  ...,  0.0184, -0.2130,  0.0093]],
#        grad_fn=<AddmmBackward0>)

# %%
plt.plot(yhat.detach()[:,0])

# %%
print(corrects.sum().item())
plt.plot(nn.functional.softmax(yhat[0,:],dim=0).detach().numpy())
plt.show()
# Out:
# 1

# %% [markdown]
# ### Model evaluation

# %%
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[-0.0022, -0.0032, -0.0020,  ..., -0.0028, -0.0016, -0.0026],
#          [ 0.0038,  0.0063,  0.0061,  ...,  0.0073,  0.0069,  0.0077],
#          [-0.0011, -0.0021, -0.0030,  ..., -0.0028, -0.0019, -0.0009],
#          ...,
#          [-0.0034, -0.0036, -0.0015,  ..., -0.0021, -0.0021, -0.0025],
#          [-0.0014, -0.0026, -0.0028,  ..., -0.0033, -0.0027, -0.0042],
#          [-0.0006, -0.0027, -0.0002,  ..., -0.0021, -0.0006, -0.0017]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-9.3830e-04,  1.4449e-04,  1.0668e-03, -1.7814e-03, -6.7264e-04,
#          -7.1423e-04, -7.9271e-04,  7.5173e-04,  1.3151e-03,  3.8234e-04,
#           2.2107e-04,  3.1005e-04, -4.3021e-04,  1.3550e-04, -7.4482e-04,
#           1.2317e-03,  1.1400e-03, -7.1479e-04, -1.6300e-04, -1.5588e-04,
#           5.2634e-04,  2.1906e-04, -1.0933e-04,  1.1681e-03,  3.1861e-04,
#           3.0522e-04,  2.0317e-03,  1.1208e-03, -3.7938e-04, -3.6237e-04,
#          -5.0126e-04, -1.1069e-03, -5.9563e-04, -5.2417e-05, -1.3696e-03,
#          -1.0810e-03, -7.0952e-05, -1.0040e-03, -1.9499e-03,  3.4779e-04,
#          -3.6580e-04, -6.6598e-05,  9.4812e-04, -2.6852e-04,  5.4147e-04,
#           1.9831e-04, -7.1278e-04,  9.7284e-05, -2.0730e-04,  1.5692e-03,
#          -7.7102e-04,  1.6764e-04, -4.0298e-04, -1.2205e-03,  3.0336e-04,
#          -9.3877e-05, -1.4899e-03, -3.8293e-04, -1.1302e-03,  4.2228e-04,
#           1.1603e-03,  6.5599e-04,  1.9614e-04, -7.4747e-04,  2.6393e-04,
#           7.9366e-05,  2.3744e-03, -2.7133e-04, -1.4343e-03,  3.5377e-04,
#           3.9949e-04, -2.7283e-04, -1.1359e-03,  3.6713e-04,  6.1869e-04,
#          -2.0145e-04, -5.9622e-04, -3.2776e-04,  1.6945e-04,  6.1616e-05,
#           2.1969e-04,  1.8130e-04, -9.9299e-04, -1.1186e-03,  9.9812e-04,
#          -9.0746e-04,  1.2863e-03, -8.8408e-04,  5.5042e-04,  2.4944e-04,
#           1.7533e-04,  9.8474e-04,  1.3142e-04,  4.6005e-04,  1.0842e-03,
#          -7.1037e-04,  1.2169e-03, -3.1081e-04, -5.0792e-04,  1.9880e-03,
#           5.3864e-04,  3.5386e-04,  2.3973e-04, -7.7317e-04, -1.0447e-03,
#           2.0529e-03,  1.1386e-03, -4.0104e-04, -2.9603e-04,  3.8709e-04,
#          -1.6106e-04, -1.0267e-03,  5.0913e-04,  1.0603e-03, -5.2538e-04,
#          -5.3133e-04,  5.5510e-06,  1.5913e-03, -2.2207e-04, -9.9011e-04,
#           2.0106e-04, -2.2319e-04,  7.9784e-04, -3.8560e-04,  2.5192e-04,
#          -1.0345e-03, -1.3236e-04,  2.1209e-04, -3.8148e-04,  1.6389e-04,
#           1.8733e-04, -1.6603e-04,  4.2726e-04,  1.1480e-03,  1.4201e-04,
#          -8.4060e-04, -1.2282e-04,  2.8330e-04, -3.8909e-04, -5.2754e-06,
#           2.8024e-03,  9.1498e-05, -1.4033e-03, -9.1502e-04,  5.3105e-04,
#           5.2584e-05,  2.1887e-04,  1.1643e-03, -8.6907e-04,  7.4744e-05,
#          -5.3551e-04,  1.4536e-03,  1.9181e-04, -1.6603e-04, -9.8798e-04,
#          -1.4259e-03,  1.2975e-03,  4.9266e-04, -1.7563e-04,  5.8033e-04,
#           9.2992e-05,  1.3605e-04,  8.0105e-04,  8.4102e-06,  1.2967e-03,
#          -3.7313e-04, -1.1150e-03,  3.1644e-04, -4.5921e-04, -7.9463e-04,
#          -4.7130e-04,  4.6215e-04,  2.0360e-03, -5.5434e-04,  3.3248e-04,
#           8.4757e-04, -5.9447e-04, -9.3018e-04, -3.3016e-04,  7.1837e-04,
#           1.2084e-03,  5.8333e-04,  7.2902e-04, -6.1360e-04,  1.1846e-03,
#          -4.3993e-04, -8.3516e-04, -4.1452e-04, -3.9016e-04, -5.9382e-05,
#          -1.0072e-03, -3.6605e-04, -1.0701e-03, -1.2884e-03, -2.9949e-04,
#          -4.0609e-04,  1.1854e-03,  3.2334e-04,  4.0709e-04,  5.1116e-04,
#          -1.8328e-03,  4.5785e-04,  1.7928e-04,  3.3892e-04, -6.2326e-04,
#          -6.0650e-05,  1.5497e-03, -9.8099e-04,  2.1073e-04,  1.7769e-05,
#          -1.1139e-04,  1.2258e-03,  9.1145e-04,  1.8933e-03,  1.2585e-03,
#          -2.7558e-04,  5.4098e-04, -5.8686e-04,  1.2108e-03,  2.0543e-04,
#          -1.2425e-04, -3.3521e-04, -8.3441e-04, -1.7081e-03,  1.0761e-03,
#           9.2245e-04, -8.7722e-04, -3.9850e-04,  1.1088e-03,  1.5689e-03,
#          -3.2067e-04, -1.8612e-04,  2.8310e-04,  3.3448e-04, -9.0893e-04,
#          -1.1170e-03, -4.5423e-04,  9.2096e-04,  3.5646e-04, -2.1507e-04,
#           4.4045e-04,  6.3126e-04, -5.1930e-04, -4.2080e-04, -1.8028e-03,
#           1.1661e-03, -3.2481e-04, -2.7782e-04, -2.1517e-04,  5.5512e-04],
#         requires_grad=True)]

# %%
def test():
    model.eval()
    logits, accs = model(), []
    for _, mask in data('train_mask', 'val_mask', 'test_mask'):
        pred = logits[mask].max(1)[1]
        acc = pred.eq(data.y[mask]).sum().item() / mask.sum().item()
        accs.append(acc)
    return accs

# %% [markdown]
# ### GCNConv

# %%
# GCN model with 3 layers 
class Net(torch.nn.Module):
    def __init__(self, n_hidden):
        super(Net, self).__init__()
        num_classes = data.num_nodes
        self.conv1 = GCNConv(data.num_features, n_hidden, add_self_loops=False)
        self.conv2 = GCNConv(n_hidden, n_hidden, add_self_loops=False)
        self.conv3 = GCNConv(n_hidden, int(num_classes), add_self_loops=False)
        # How to include edge weights? 
        
    def forward(self):
        x, edge_index = data.x, data.edge_index
        x = nn.functional.relu(self.conv1(x, edge_index))
        x = nn.functional.dropout(x, training=self.training)
        x = nn.functional.relu(self.conv2(x, edge_index))
        x = nn.functional.dropout(x, training=self.training)
        x = self.conv3(x, edge_index)
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
num_hidden = 250
model, data = Net(num_hidden).to(device), data.to(device)

torch.manual_seed(42)

# optimizer = torch.optim.Adam(model.parameters(), lr=0.0075, weight_decay=0.05)
optimizer = torch.optim.SGD(model.parameters(), lr=0.5, momentum=0.1, dampening=0, weight_decay=0.05)
scheduler = ExponentialLR(optimizer, gamma=0.9)
criterion = nn.CrossEntropyLoss() # computes softmax and then the cross entropy

# %%
train_acc = []
for ii, epoch in enumerate(range(1, 101)):
    model.train(True) # for gradient tracking 
    
    optimizer.zero_grad()
    yhat = model()
    loss = criterion(yhat, data.y)
    loss.backward()
    optimizer.step()
    scheduler.step()
    
    model.train(False) # don't need to track gradients for metrics
    corrects = (yhat.argmax(dim=0) == data.y.argmax(dim=0))
    train_acc.append( (corrects.sum()/data.y.size(1)).item() )
    if epoch % 10 == 0: 
        print(f'Epoch: {epoch:03d}, Train: {train_acc[ii]:.4f}')
    
plt.plot(train_acc)
# Out:
# Epoch: 010, Train: 0.0080
# Epoch: 020, Train: 0.0120
# Epoch: 030, Train: 0.0080
# Epoch: 040, Train: 0.0040
# Epoch: 050, Train: 0.0040
# Epoch: 060, Train: 0.0040
# Epoch: 070, Train: 0.0080
# Epoch: 080, Train: 0.0120
# Epoch: 090, Train: 0.0040
# Epoch: 100, Train: 0.0080

# %%
corrects.sum()
# Out:
# tensor(1)

# %% [markdown]
# ### Logistic Regression on fitness data to classify gene knockdown

# %%
from sklearn.linear_model import LogisticRegression

# %%
y = np.arange(0,data.num_nodes)

# %%
lr = LogisticRegression(multi_class='multinomial',C=10)
lr = lr.fit(data.x.numpy(), y)
# y_pred = lr_iris.predict(X)

# %%
lr.predict(data.x.numpy())
# Out:
# array([  0,  46,  56, 213,  22,   5, 173,  36,   8,   9,  10, 197,  12,
#         82,  14,  82, 191, 137, 173,  19, 177, 169,  22, 244,  24, 158,
#        219,  27,  63, 185,  12, 233,  97,  33, 148,  97,  36, 213,  63,
#          5, 249,  41,  30,  12,  44, 180,  46, 146, 121, 197, 219,  51,
#         52, 173, 108, 162,  56,  57, 185,  85,  60,  12,  10,  63,  64,
#         24, 155,  67,  71, 235,  70,  82,  72,   9, 110,  75, 108,  77,
#        190,  93,  80, 110,  82,  83,  92,  72,  86, 148,  88, 110,  90,
#        173,  92,  93, 117, 151,  96,  97,  98, 231, 100, 101, 102, 103,
#        104, 105, 106, 107, 108, 109, 110, 110, 110, 113, 240,  46,   4,
#        117, 248,   9, 120, 121, 122, 123, 124, 108,  80, 127, 128, 129,
#        130, 108, 139, 233, 246, 213, 136, 137, 138,  82, 173, 141, 157,
#        177, 246,  98, 146, 216, 148, 110,  70, 151, 152, 110, 117,   5,
#         82, 157, 173, 159, 185,  92, 185, 163, 164, 165,  98, 219,   8,
#        169,  97, 171, 175, 173, 233, 175, 219, 177, 173, 179, 180,   7,
#        130, 183, 249, 185, 110,  82, 188, 189, 190, 191,  90, 190, 123,
#        195,  54, 197,  82, 244, 148,  89, 207, 243, 204, 244,   4, 207,
#         12,  85,  12, 219, 188, 213,  50, 215, 188, 219, 218, 219, 220,
#        221,  97,  71, 173, 148, 191, 227, 158, 229,  70, 231,  46, 233,
#         57,  72, 236, 237, 180, 213, 233, 110,  57, 243, 244, 245, 246,
#        247, 248, 249])

# %%
lr.coef_.shape
# Out:
# (250, 7)

# %%
data.x.numpy().shape
# Out:
# (250, 7)

# %%
len(np.where(lr.predict(data.x.numpy()) - y==0)[0])/250
# Out:
# 0.44

# %%
len(np.where(lr.predict(x_test) - y==0)[0])/250
# Out:
# 0.016
